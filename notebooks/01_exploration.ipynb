# %% [markdown]
# # EDA, profiling, sanity checks

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
# Import data
micro_stop = pd.read_csv('D:/INFORMATIQUE/Data Analysis/Data_Analysis_Projects/Project_OPEX_Downtime_and_OEE_Analysis/dataset/raw_data/micro_stops.csv')
oee_daily = pd.read_csv('D:/INFORMATIQUE/Data Analysis/Data_Analysis_Projects/Project_OPEX_Downtime_and_OEE_Analysis/dataset/raw_data/oee_daily.csv')
quality_defects = pd.read_csv('D:/INFORMATIQUE/Data Analysis/Data_Analysis_Projects/Project_OPEX_Downtime_and_OEE_Analysis/dataset/raw_data/quality_defects.csv')
ref_lines = pd.read_csv('D:/INFORMATIQUE/Data Analysis/Data_Analysis_Projects/Project_OPEX_Downtime_and_OEE_Analysis/dataset/raw_data/ref_lines.csv')
stops = pd.read_csv('D:/INFORMATIQUE/Data Analysis/Data_Analysis_Projects/Project_OPEX_Downtime_and_OEE_Analysis/dataset/raw_data/stops.csv')
